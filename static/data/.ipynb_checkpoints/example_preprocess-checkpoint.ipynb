# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./example_data/all_2-Copy1.csv')

# %%
df2 = pd.DataFrame()
countries = ['Germany', 'Sweden', 'Italy', 'Finland', 'Austria', 'Spain', 'France', 'Denmark']
for index, row in df.iterrows():
    if index % 10000 == 0: print(index)
    if row['Country Name'] in countries:
        df2 = df2.append(row)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-3cfc0e685f52> in <module>()
#       4     if row['Country Name'] in countries:
#       5         if index % 10000 == 0: print(index)
# ----> 6         df2 = df2.append(row)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6209         return concat(to_concat, ignore_index=ignore_index,
#    6210                       verify_integrity=verify_integrity,
# -> 6211                       sort=sort)
#    6212
#    6213     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     224                        verify_integrity=verify_integrity,
# ...

# %%
len(df2)
# Out:
# 62464

# %%
df2.to_csv('./all2_preprocessed.csv')

# %%
df
# Out:
#         Unnamed: 0  Unnamed: 0.1 Country Name  \
# 0                0             0        Aruba
# 1                1             1        Aruba
# 2                2             2        Aruba
# 3                3             3        Aruba
# 4                4             4        Aruba
# 5                5             5        Aruba
# 6                6             6        Aruba
# 7                7             7        Aruba
# 8                8             8        Aruba
# 9                9             9        Aruba
# 10              10            10        Aruba
# 11              11            11        Aruba
# 12              12            12        Aruba
# 13              13            13        Aruba
# 14              14            14        Aruba
# 15              15            15        Aruba
# 16              16            16        Aruba
# 17              17            17        Aruba
# 18              18            18        Aruba
# ...
