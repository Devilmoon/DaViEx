# %%
import pandas as pd
import numpy as np

# %%
co2_emission_kt = pd.read_csv('../data/CO2_emission_kt.csv')
co2_emission_per_capita = pd.read_csv('../data/CO2_emissions_per_capita.csv')
electric_power_consumption = pd.read_csv('../data/electric_power_consumption.csv')
energy_use_kg_of_oil_equivalent_per_capita = pd.read_csv('../data/energy_use_kg_of_oil_equivalent_per_capita.csv')
gdp = pd.read_csv('../data/GDP.csv')
gdp_growth = pd.read_csv('../data/GDP_growth.csv')
gdp_per_capita = pd.read_csv('../data/GDP_per_capita.csv')
gdp_per_capita_growth = pd.read_csv('../data/GDP_per_capita_growth.csv')
gdp_per_unit_of_energy_use = pd.read_csv('../data/GDP_per_unit_of_energy_use.csv')
renewable_elecricity_ouput = pd.read_csv('../data/renewable_elecricity_ouput.csv')
renewable_energy_consumption = pd.read_csv('../data/renewable_energy_consumption.csv')
fossil_fuel_energy_consumption = pd.read_csv('../data/fossil_fuel_energy_consumption.csv')
alternative_and_nuclear_energy = pd.read_csv('../data/alternative_and_nuclear_energy.csv')

# %%
co2_emission_kt.head()
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code      1960  \
# 0        Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 1  Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# 2       Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# 3      Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
# 4      Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
#
#        1961      1962      1963      1964      1965     ...            2009  \
# 0       NaN       NaN       NaN       NaN       NaN     ...        2629.239
# 1   491.378   689.396   707.731   839.743  1008.425     ...        6769.282
# 2   454.708  1180.774  1151.438  1224.778  1188.108     ...       27792.193
# 3  2280.874  2464.224  2082.856  2016.850  2174.531     ...        4378.398
# 4       NaN       NaN       NaN       NaN       NaN     ...         517.047
#
# ...

# %%
co2_emission_per_capita.head()
# Out:
#   Country Name Country Code                          Indicator Name  \
# 0        Aruba          ABW  CO2 emissions (metric tons per capita)
# 1  Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2       Angola          AGO  CO2 emissions (metric tons per capita)
# 3      Albania          ALB  CO2 emissions (metric tons per capita)
# 4      Andorra          AND  CO2 emissions (metric tons per capita)
#
#    Indicator Code      1960      1961      1962      1963      1964      1965  \
# 0  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
# 1  EN.ATM.CO2E.PC  0.046060  0.053604  0.073765  0.074233  0.086292  0.101467
# 2  EN.ATM.CO2E.PC  0.097472  0.079038  0.201289  0.192535  0.201003  0.191528
# 3  EN.ATM.CO2E.PC  1.258195  1.374186  1.439956  1.181681  1.111742  1.166099
# 4  EN.ATM.CO2E.PC       NaN       NaN       NaN       NaN       NaN       NaN
#
#       ...            2009       2010       2011       2012      2013  \
# ...

# %%
electric_power_consumption.head()
# Out:
#   Country Name Country Code                               Indicator Name  \
# 0        Aruba          ABW  Electric power consumption (kWh per capita)
# 1  Afghanistan          AFG  Electric power consumption (kWh per capita)
# 2       Angola          AGO  Electric power consumption (kWh per capita)
# 3      Albania          ALB  Electric power consumption (kWh per capita)
# 4      Andorra          AND  Electric power consumption (kWh per capita)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965     ...       \
# 0  EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 1  EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 2  EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 3  EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 4  EG.USE.ELEC.KH.PC   NaN   NaN   NaN   NaN   NaN   NaN     ...
#
#           2009         2010         2011         2012         2013  \
# ...

# %%
energy_use_kg_of_oil_equivalent_per_capita.head()
# Out:
#   Country Name Country Code                                Indicator Name  \
# 0        Aruba          ABW  Energy use (kg of oil equivalent per capita)
# 1  Afghanistan          AFG  Energy use (kg of oil equivalent per capita)
# 2       Angola          AGO  Energy use (kg of oil equivalent per capita)
# 3      Albania          ALB  Energy use (kg of oil equivalent per capita)
# 4      Andorra          AND  Energy use (kg of oil equivalent per capita)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965     ...       \
# 0  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 1  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 2  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 3  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 4  EG.USE.PCAP.KG.OE   NaN   NaN   NaN   NaN   NaN   NaN     ...
#
#          2009        2010        2011        2012        2013        2014  \
# ...

# %%
gdp.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code          1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD           NaN
#
#            1961          1962          1963          1964          1965  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
# ...

# %%
gdp_growth.head()
# Out:
#   Country Name Country Code         Indicator Name     Indicator Code  1960  \
# 0        Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 1  Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 2       Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 3      Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 4      Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#    1961  1962  1963  1964  1965     ...            2009      2010      2011  \
# 0   NaN   NaN   NaN   NaN   NaN     ...       -5.653502       NaN       NaN
# 1   NaN   NaN   NaN   NaN   NaN     ...       21.020649  8.433290  6.113685
# 2   NaN   NaN   NaN   NaN   NaN     ...        2.412910  3.452875  3.873331
# 3   NaN   NaN   NaN   NaN   NaN     ...        3.352610  3.710058  2.550161
# 4   NaN   NaN   NaN   NaN   NaN     ...       -3.690654 -5.358826 -4.646543
#
# ...

# %%
gdp_per_capita.head()
# Out:
#   Country Name Country Code                Indicator Name  Indicator Code  \
# 0        Aruba          ABW  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1  Afghanistan          AFG  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 2       Angola          AGO  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 3      Albania          ALB  GDP per capita (current US$)  NY.GDP.PCAP.CD
# 4      Andorra          AND  GDP per capita (current US$)  NY.GDP.PCAP.CD
#
#         1960       1961       1962       1963       1964        1965  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1  59.777327  59.878153  58.492874  78.782758  82.208444  101.290471
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN
#
#       ...               2009          2010          2011          2012  \
# ...

# %%
gdp_per_capita_growth.head()
# Out:
#   Country Name Country Code                    Indicator Name  \
# 0        Aruba          ABW  GDP per capita growth (annual %)
# 1  Afghanistan          AFG  GDP per capita growth (annual %)
# 2       Angola          AGO  GDP per capita growth (annual %)
# 3      Albania          ALB  GDP per capita growth (annual %)
# 4      Andorra          AND  GDP per capita growth (annual %)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965     ...       \
# 0  NY.GDP.PCAP.KD.ZG   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 1  NY.GDP.PCAP.KD.ZG   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 2  NY.GDP.PCAP.KD.ZG   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 3  NY.GDP.PCAP.KD.ZG   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 4  NY.GDP.PCAP.KD.ZG   NaN   NaN   NaN   NaN   NaN   NaN     ...
#
#         2009      2010      2011       2012      2013      2014      2015  \
# 0  -5.746497       NaN       NaN        NaN       NaN       NaN       NaN
# ...

# %%
gdp_per_unit_of_energy_use.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name        Indicator Code  \
# 0  GDP per unit of energy use (constant 2011 PPP ...  EG.GDP.PUSE.KO.PP.KD
# 1  GDP per unit of energy use (constant 2011 PPP ...  EG.GDP.PUSE.KO.PP.KD
# 2  GDP per unit of energy use (constant 2011 PPP ...  EG.GDP.PUSE.KO.PP.KD
# 3  GDP per unit of energy use (constant 2011 PPP ...  EG.GDP.PUSE.KO.PP.KD
# 4  GDP per unit of energy use (constant 2011 PPP ...  EG.GDP.PUSE.KO.PP.KD
#
#    1960  1961  1962  1963  1964  1965     ...            2009       2010  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN     ...       11.485054  11.326992
# ...

# %%
renewable_elecricity_ouput.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Renewable electricity output (% of total elect...  EG.ELC.RNEW.ZS   NaN
# 1  Renewable electricity output (% of total elect...  EG.ELC.RNEW.ZS   NaN
# 2  Renewable electricity output (% of total elect...  EG.ELC.RNEW.ZS   NaN
# 3  Renewable electricity output (% of total elect...  EG.ELC.RNEW.ZS   NaN
# 4  Renewable electricity output (% of total elect...  EG.ELC.RNEW.ZS   NaN
#
#    1961  1962  1963  1964  1965     ...            2009       2010       2011  \
# 0   NaN   NaN   NaN   NaN   NaN     ...        0.000000  11.327377  12.101021
# 1   NaN   NaN   NaN   NaN   NaN     ...       87.176603  85.986547  82.487562
# 2   NaN   NaN   NaN   NaN   NaN     ...       65.343189  67.957423  70.907804
# ...

# %%
renewable_energy_consumption.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS   NaN
# 1  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS   NaN
# 2  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS   NaN
# 3  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS   NaN
# 4  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS   NaN
#
#    1961  1962  1963  1964  1965     ...            2009       2010       2011  \
# 0   NaN   NaN   NaN   NaN   NaN     ...        0.299774   5.464716   5.661788
# 1   NaN   NaN   NaN   NaN   NaN     ...       17.813855  14.839806  11.482706
# 2   NaN   NaN   NaN   NaN   NaN     ...       55.748977  54.193837  52.715679
# ...

# %%
fossil_fuel_energy_consumption.head()
# Out:
#   Country Name Country Code                               Indicator Name  \
# 0        Aruba          ABW  Fossil fuel energy consumption (% of total)
# 1  Afghanistan          AFG  Fossil fuel energy consumption (% of total)
# 2       Angola          AGO  Fossil fuel energy consumption (% of total)
# 3      Albania          ALB  Fossil fuel energy consumption (% of total)
# 4      Andorra          AND  Fossil fuel energy consumption (% of total)
#
#       Indicator Code  1960  1961  1962  1963  1964  1965     ...       \
# 0  EG.USE.COMM.FO.ZS   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 1  EG.USE.COMM.FO.ZS   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 2  EG.USE.COMM.FO.ZS   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 3  EG.USE.COMM.FO.ZS   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 4  EG.USE.COMM.FO.ZS   NaN   NaN   NaN   NaN   NaN   NaN     ...
#
#         2009       2010       2011       2012       2013       2014  2015  \
# ...
